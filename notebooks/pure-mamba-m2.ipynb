# %%
# %uv pip install scikit-learn ipywidgets jupyterlab
# Out:
# Using Python 3.10.13 environment at: /usr/local
# Resolved 101 packages in 318ms
# ⠙ Preparing packages... (0/54)
# ⠙ Preparing packages... (0/54)
# ⠙ Preparing packages... (0/54)
# ⠙ Preparing packages... (0/54)
# argon2-cffi          ------------------------------     0 B/14.31 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi          ------------------------------ 14.31 KiB/14.31 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi          ------------------------------ 14.31 KiB/14.31 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi          ------------------------------ 14.31 KiB/14.31 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi          ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger   ------------------------------     0 B/15.18 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi          ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger   ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger   ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# jupyter-server-terminals ------------------------------     0 B/13.38 KiB
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# jupyter-server-terminals ------------------------------ 13.38 KiB/13.38 KiB
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# jupyter-server-terminals ------------------------------ 13.38 KiB/13.38 KiB
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# jupyter-server-terminals ------------------------------ 13.38 KiB/13.38 KiB
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# jupyter-server-terminals ------------------------------ 13.38 KiB/13.38 KiB
# argon2-cffi              ------------------------------ 14.31 KiB/14.31 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# ⠙ Preparing packages... (0/54)
# async-lru                ------------------------------ 8.21 KiB/8.21 KiB
# fqdn                     ------------------------------ 8.91 KiB/8.91 KiB
# uri-template             ------------------------------ 10.88 KiB/10.88 KiB
# webencodings             ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim            ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals ------------------------------ 13.38 KiB/13.38 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# send2trash               ------------------------------ 14.91 KiB/17.20 KiB
# jsonschema               ------------------------------     0 B/88.51 KiB
# ⠙ Preparing packages... (0/54)
# async-lru                ------------------------------ 8.21 KiB/8.21 KiB
# fqdn                     ------------------------------ 8.91 KiB/8.91 KiB
# uri-template             ------------------------------ 10.88 KiB/10.88 KiB
# isoduration              ------------------------------   315 B/11.06 KiB
# webencodings             ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim            ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals ------------------------------ 13.38 KiB/13.38 KiB
# terminado                ------------------------------ 13.82 KiB/13.82 KiB
# tomli                    ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger       ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments      ------------------------------ 14.90 KiB/15.51 KiB
# send2trash               ------------------------------ 14.91 KiB/17.20 KiB
# overrides                ------------------------------ 14.91 KiB/17.41 KiB
# fastjsonschema           ------------------------------ 14.88 KiB/23.46 KiB
# nbclient                 ------------------------------ 14.91 KiB/24.87 KiB
# tinycss2                 ------------------------------ 14.92 KiB/25.99 KiB
# json5                    ------------------------------ 14.92 KiB/35.32 KiB
# soupsieve                ------------------------------ 14.91 KiB/36.15 KiB
# mistune                  ------------------------------ 14.90 KiB/52.34 KiB
# jupyterlab-server        ------------------------------ 14.91 KiB/58.43 KiB
# jsonschema               ------------------------------ 14.91 KiB/88.51 KiB
# ⠙ Preparing packages... (0/54)
# pandocfilters             ------------------------------ 8.46 KiB/8.46 KiB
# fqdn                      ------------------------------ 8.91 KiB/8.91 KiB
# uri-template              ------------------------------ 10.88 KiB/10.88 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# webencodings              ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# send2trash                ------------------------------ 14.91 KiB/17.20 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 14.94 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 14.88 KiB/23.46 KiB
# nbclient                  ------------------------------ 14.91 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 14.92 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# ⠙ Preparing packages... (0/54)
# pandocfilters             ------------------------------ 8.46 KiB/8.46 KiB
# fqdn                      ------------------------------ 8.91 KiB/8.91 KiB
# uri-template              ------------------------------ 10.88 KiB/10.88 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# webencodings              ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# send2trash                ------------------------------ 14.91 KiB/17.20 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 14.94 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 14.88 KiB/23.46 KiB
# nbclient                  ------------------------------ 14.91 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 14.92 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# ⠙ Preparing packages... (0/54)
# pandocfilters             ------------------------------ 8.46 KiB/8.46 KiB
# uri-template              ------------------------------ 10.88 KiB/10.88 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# webencodings              ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# send2trash                ------------------------------ 14.91 KiB/17.20 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 14.94 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 14.88 KiB/23.46 KiB
# nbclient                  ------------------------------ 14.91 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 14.92 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 14.92 KiB/35.32 KiB
# ⠙ Preparing packages... (0/54)
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# pandocfilters             ------------------------------ 8.46 KiB/8.46 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# webencodings              ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# send2trash                ------------------------------ 17.20 KiB/17.20 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 14.94 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 14.88 KiB/23.46 KiB
# nbclient                  ------------------------------ 14.91 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 14.92 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 30.92 KiB/35.32 KiB
# ⠙ Preparing packages... (0/54)
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# pandocfilters             ------------------------------ 8.46 KiB/8.46 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# webencodings              ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 18.20 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 14.88 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 14.92 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 30.92 KiB/35.32 KiB
# soupsieve                 ------------------------------ 30.91 KiB/36.15 KiB
# ⠙ Preparing packages... (0/54)
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# pandocfilters             ------------------------------ 8.46 KiB/8.46 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# webencodings              ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 18.20 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 14.92 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 30.92 KiB/35.32 KiB
# soupsieve                 ------------------------------ 30.91 KiB/36.15 KiB
# ⠙ Preparing packages... (0/54)
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# webencodings              ------------------------------ 11.50 KiB/11.50 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 18.20 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 30.92 KiB/35.32 KiB
# ⠙ Preparing packages... (0/54)
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# threadpoolctl             ------------------------------ 18.20 KiB/18.20 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 30.92 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# ⠙ Preparing packages... (0/54)
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 14.91 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 30.92 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------     0 B/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# jupyter-server-terminals  ------------------------------ 13.38 KiB/13.38 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 17.41 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 14.91 KiB/26.14 KiB
# json5                     ------------------------------ 30.92 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 17.41 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 17.41 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# tomli                     ------------------------------ 14.14 KiB/14.14 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 17.41 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# python-json-logger        ------------------------------ 14.90 KiB/15.18 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 17.41 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# overrides                 ------------------------------ 17.41 KiB/17.41 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# webcolors                 ------------------------------ 14.56 KiB/14.56 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# soupsieve                 ------------------------------ 36.15 KiB/36.15 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# notebook-shim             ------------------------------ 13.00 KiB/13.00 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 14.86 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# nbformat                  ------------------------------ 30.91 KiB/76.62 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# rfc3987-syntax            ------------------------------ 7.86 KiB/7.86 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 25.00 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# nbformat                  ------------------------------ 30.91 KiB/76.62 KiB
# websocket-client          ------------------------------ 36.66 KiB/80.68 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# terminado                 ------------------------------ 13.82 KiB/13.82 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 25.00 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# nbformat                  ------------------------------ 30.91 KiB/76.62 KiB
# websocket-client          ------------------------------ 36.66 KiB/80.68 KiB
# jsonschema                ------------------------------ 36.04 KiB/88.51 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 25.00 KiB/25.00 KiB
# tinycss2                  ------------------------------ 25.99 KiB/25.99 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# nbformat                  ------------------------------ 30.91 KiB/76.62 KiB
# websocket-client          ------------------------------ 36.66 KiB/80.68 KiB
# jsonschema                ------------------------------ 36.04 KiB/88.51 KiB
# beautifulsoup4            ------------------------------ 78.89 KiB/105.20 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# rfc3986-validator         ------------------------------ 4.14 KiB/4.14 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 25.00 KiB/25.00 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 62.89 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# nbformat                  ------------------------------ 30.91 KiB/76.62 KiB
# websocket-client          ------------------------------ 36.66 KiB/80.68 KiB
# jsonschema                ------------------------------ 36.04 KiB/88.51 KiB
# beautifulsoup4            ------------------------------ 94.89 KiB/105.20 KiB
# lark                      ------------------------------ 62.92 KiB/110.50 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 25.00 KiB/25.00 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# json5                     ------------------------------ 35.32 KiB/35.32 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 67.18 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# nbformat                  ------------------------------ 30.91 KiB/76.62 KiB
# websocket-client          ------------------------------ 36.66 KiB/80.68 KiB
# jsonschema                ------------------------------ 36.04 KiB/88.51 KiB
# beautifulsoup4            ------------------------------ 94.89 KiB/105.20 KiB
# lark                      ------------------------------ 62.92 KiB/110.50 KiB
# ipywidgets                ------------------------------ 30.94 KiB/136.53 KiB
# ⠹ Preparing packages... (8/54)
# rfc3339-validator         ------------------------------ 3.41 KiB/3.41 KiB
# jsonpointer               ------------------------------ 7.42 KiB/7.42 KiB
# isoduration               ------------------------------ 11.06 KiB/11.06 KiB
# jupyterlab-pygments       ------------------------------ 14.90 KiB/15.51 KiB
# jsonschema-specifications ------------------------------ 14.89 KiB/18.00 KiB
# jupyter-events            ------------------------------ 14.94 KiB/18.97 KiB
# fastjsonschema            ------------------------------ 23.46 KiB/23.46 KiB
# nbclient                  ------------------------------ 24.87 KiB/24.87 KiB
# defusedxml                ------------------------------ 25.00 KiB/25.00 KiB
# referencing               ------------------------------ 26.14 KiB/26.14 KiB
# mistune                   ------------------------------ 30.90 KiB/52.34 KiB
# jupyterlab-server         ------------------------------ 30.91 KiB/58.43 KiB
# prometheus-client         ------------------------------ 46.90 KiB/62.56 KiB
# arrow                     ------------------------------ 67.18 KiB/67.18 KiB
# jupyter-lsp               ------------------------------ 30.84 KiB/74.89 KiB
# nbformat                  ------------------------------ 30.91 KiB/76.62 KiB
# websocket-client          ------------------------------ 36.66 KiB/80.68 KiB
# jsonschema                ------------------------------ 36.04 KiB/88.51 KiB
# beautifulsoup4            ------------------------------ 94.89 KiB/105.20 KiB
# lark                      ------------------------------ 62.92 KiB/110.50 KiB
# ...
# jupyter-server            ------------------------------ 222.10 KiB/379.12 KiB
# widgetsnbextension        ------------------------------ 1.92 MiB/2.09 MiB
# scikit-learn              ------------------------------ 1.62 MiB/9.21 MiB
# babel                     ------------------------------ 858.77 KiB/9.72 MiB
# jupyterlab                ------------------------------ 132.25 KiB/11.87 MiB
# ⠼ Preparing packages... (43/54)
# nbconvert                 ------------------------------ 219.75 KiB/255.38 KiB
# joblib                    ------------------------------ 286.46 KiB/301.83 KiB
# tzdata                    ------------------------------ 92.60 KiB/340.35 KiB
# jupyter-server            ------------------------------ 238.10 KiB/379.12 KiB
# widgetsnbextension        ------------------------------ 2.06 MiB/2.09 MiB
# scikit-learn              ------------------------------ 1.68 MiB/9.21 MiB
# babel                     ------------------------------ 990.77 KiB/9.72 MiB
# jupyterlab                ------------------------------ 138.95 KiB/11.87 MiB
# ⠴ Preparing packages... (45/54)
# nbconvert                 ------------------------------ 235.75 KiB/255.38 KiB
# joblib                    ------------------------------ 286.46 KiB/301.83 KiB
# tzdata                    ------------------------------ 92.60 KiB/340.35 KiB
# jupyter-server            ------------------------------ 366.10 KiB/379.12 KiB
# widgetsnbextension        ------------------------------ 2.09 MiB/2.09 MiB
# scikit-learn              ------------------------------ 1.76 MiB/9.21 MiB
# babel                     ------------------------------ 1.12 MiB/9.72 MiB
# jupyterlab                ------------------------------ 154.95 KiB/11.87 MiB
# ⠴ Preparing packages... (45/54)
# nbconvert                 ------------------------------ 235.75 KiB/255.38 KiB
# joblib                    ------------------------------ 286.46 KiB/301.83 KiB
# tzdata                    ------------------------------ 92.60 KiB/340.35 KiB
# jupyter-server            ------------------------------ 366.10 KiB/379.12 KiB
# scikit-learn              ------------------------------ 1.76 MiB/9.21 MiB
# babel                     ------------------------------ 1.18 MiB/9.72 MiB
# jupyterlab                ------------------------------ 154.95 KiB/11.87 MiB
# ⠴ Preparing packages... (45/54)
# nbconvert                 ------------------------------ 235.75 KiB/255.38 KiB
# joblib                    ------------------------------ 286.46 KiB/301.83 KiB
# tzdata                    ------------------------------ 108.60 KiB/340.35 KiB
# jupyter-server            ------------------------------ 366.10 KiB/379.12 KiB
# scikit-learn              ------------------------------ 1.81 MiB/9.21 MiB
# babel                     ------------------------------ 1.36 MiB/9.72 MiB
# jupyterlab                ------------------------------ 154.95 KiB/11.87 MiB
# ⠴ Preparing packages... (45/54)
# nbconvert                 ------------------------------ 235.75 KiB/255.38 KiB
# joblib                    ------------------------------ 286.46 KiB/301.83 KiB
# tzdata                    ------------------------------ 108.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 1.93 MiB/9.21 MiB
# babel                     ------------------------------ 1.36 MiB/9.72 MiB
# jupyterlab                ------------------------------ 154.95 KiB/11.87 MiB
# ⠴ Preparing packages... (45/54)
# nbconvert                 ------------------------------ 251.75 KiB/255.38 KiB
# tzdata                    ------------------------------ 108.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.00 MiB/9.21 MiB
# babel                     ------------------------------ 1.42 MiB/9.72 MiB
# jupyterlab                ------------------------------ 170.95 KiB/11.87 MiB
# ⠴ Preparing packages... (45/54)
# nbconvert                 ------------------------------ 251.75 KiB/255.38 KiB
# tzdata                    ------------------------------ 108.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.00 MiB/9.21 MiB
# babel                     ------------------------------ 1.42 MiB/9.72 MiB
# jupyterlab                ------------------------------ 170.95 KiB/11.87 MiB
# ⠴ Preparing packages... (45/54)
# tzdata                    ------------------------------ 108.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.06 MiB/9.21 MiB
# babel                     ------------------------------ 1.42 MiB/9.72 MiB
# jupyterlab                ------------------------------ 170.95 KiB/11.87 MiB
# ⠦ Preparing packages... (49/54)
# tzdata                    ------------------------------ 108.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.06 MiB/9.21 MiB
# babel                     ------------------------------ 1.42 MiB/9.72 MiB
# jupyterlab                ------------------------------ 170.95 KiB/11.87 MiB
# ⠦ Preparing packages... (49/54)
# tzdata                    ------------------------------ 108.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.09 MiB/9.21 MiB
# babel                     ------------------------------ 1.61 MiB/9.72 MiB
# jupyterlab                ------------------------------ 170.95 KiB/11.87 MiB
# ⠦ Preparing packages... (49/54)
# tzdata                    ------------------------------ 123.13 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.44 MiB/9.21 MiB
# babel                     ------------------------------ 1.92 MiB/9.72 MiB
# jupyterlab                ------------------------------ 1.18 MiB/11.87 MiB
# ⠦ Preparing packages... (49/54)
# tzdata                    ------------------------------ 139.13 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.47 MiB/9.21 MiB
# babel                     ------------------------------ 2.20 MiB/9.72 MiB
# jupyterlab                ------------------------------ 1.87 MiB/11.87 MiB
# ⠦ Preparing packages... (49/54)
# tzdata                    ------------------------------ 156.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.56 MiB/9.21 MiB
# babel                     ------------------------------ 2.34 MiB/9.72 MiB
# jupyterlab                ------------------------------ 2.36 MiB/11.87 MiB
# ⠧ Preparing packages... (49/54)
# tzdata                    ------------------------------ 172.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 2.75 MiB/9.21 MiB
# babel                     ------------------------------ 2.37 MiB/9.72 MiB
# jupyterlab                ------------------------------ 2.95 MiB/11.87 MiB
# ⠧ Preparing packages... (49/54)
# tzdata                    ------------------------------ 188.50 KiB/340.35 KiB
# scikit-learn              ------------------------------ 3.05 MiB/9.21 MiB
# babel                     ------------------------------ 2.39 MiB/9.72 MiB
# jupyterlab                ------------------------------ 3.23 MiB/11.87 MiB
# ⠧ Preparing packages... (49/54)
# tzdata                    ------------------------------ 204.50 KiB/340.35 KiB
# scikit-learn              ------------------------------ 3.37 MiB/9.21 MiB
# babel                     ------------------------------ 2.62 MiB/9.72 MiB
# jupyterlab                ------------------------------ 3.50 MiB/11.87 MiB
# ⠧ Preparing packages... (49/54)
# tzdata                    ------------------------------ 204.50 KiB/340.35 KiB
# scikit-learn              ------------------------------ 3.42 MiB/9.21 MiB
# babel                     ------------------------------ 2.94 MiB/9.72 MiB
# jupyterlab                ------------------------------ 3.98 MiB/11.87 MiB
# ⠇ Preparing packages... (49/54)
# tzdata                    ------------------------------ 220.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 3.52 MiB/9.21 MiB
# babel                     ------------------------------ 3.09 MiB/9.72 MiB
# jupyterlab                ------------------------------ 4.56 MiB/11.87 MiB
# ⠇ Preparing packages... (49/54)
# tzdata                    ------------------------------ 220.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 3.59 MiB/9.21 MiB
# babel                     ------------------------------ 3.26 MiB/9.72 MiB
# jupyterlab                ------------------------------ 5.60 MiB/11.87 MiB
# ⠇ Preparing packages... (49/54)
# tzdata                    ------------------------------ 236.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 3.62 MiB/9.21 MiB
# babel                     ------------------------------ 3.43 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.33 MiB/11.87 MiB
# ⠇ Preparing packages... (49/54)
# tzdata                    ------------------------------ 252.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 3.78 MiB/9.21 MiB
# babel                     ------------------------------ 3.98 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.36 MiB/11.87 MiB
# ⠋ Preparing packages... (49/54)
# tzdata                    ------------------------------ 252.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 4.00 MiB/9.21 MiB
# babel                     ------------------------------ 4.07 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.36 MiB/11.87 MiB
# ⠋ Preparing packages... (49/54)
# tzdata                    ------------------------------ 268.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 4.23 MiB/9.21 MiB
# babel                     ------------------------------ 4.24 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.44 MiB/11.87 MiB
# ⠋ Preparing packages... (49/54)
# tzdata                    ------------------------------ 268.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 4.45 MiB/9.21 MiB
# babel                     ------------------------------ 4.51 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.47 MiB/11.87 MiB
# ⠋ Preparing packages... (49/54)
# tzdata                    ------------------------------ 284.60 KiB/340.35 KiB
# scikit-learn              ------------------------------ 4.95 MiB/9.21 MiB
# babel                     ------------------------------ 4.89 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.48 MiB/11.87 MiB
# ⠙ Preparing packages... (49/54)
# scikit-learn              ------------------------------ 5.25 MiB/9.21 MiB
# babel                     ------------------------------ 4.95 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.48 MiB/11.87 MiB
# ⠙ Preparing packages... (49/54)
# scikit-learn              ------------------------------ 5.25 MiB/9.21 MiB
# babel                     ------------------------------ 4.95 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.48 MiB/11.87 MiB
# ⠙ Preparing packages... (49/54)
# scikit-learn              ------------------------------ 5.42 MiB/9.21 MiB
# babel                     ------------------------------ 5.18 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.50 MiB/11.87 MiB
# ⠙ Preparing packages... (49/54)
# scikit-learn              ------------------------------ 5.55 MiB/9.21 MiB
# babel                     ------------------------------ 5.34 MiB/9.72 MiB
# jupyterlab                ------------------------------ 6.51 MiB/11.87 MiB
# ⠙ Preparing packages... (49/54)
# scikit-learn              ------------------------------ 6.28 MiB/9.21 MiB
# babel                     ------------------------------ 5.73 MiB/9.72 MiB
# jupyterlab                ------------------------------ 7.15 MiB/11.87 MiB
# ⠹ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 6.39 MiB/9.21 MiB
# babel                     ------------------------------ 5.95 MiB/9.72 MiB
# jupyterlab                ------------------------------ 7.35 MiB/11.87 MiB
# ⠹ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 6.89 MiB/9.21 MiB
# babel                     ------------------------------ 6.34 MiB/9.72 MiB
# jupyterlab                ------------------------------ 7.86 MiB/11.87 MiB
# ⠹ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 7.29 MiB/9.21 MiB
# babel                     ------------------------------ 6.80 MiB/9.72 MiB
# jupyterlab                ------------------------------ 8.43 MiB/11.87 MiB
# ⠹ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 7.87 MiB/9.21 MiB
# babel                     ------------------------------ 7.12 MiB/9.72 MiB
# jupyterlab                ------------------------------ 8.81 MiB/11.87 MiB
# ⠸ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 8.34 MiB/9.21 MiB
# babel                     ------------------------------ 7.44 MiB/9.72 MiB
# jupyterlab                ------------------------------ 9.31 MiB/11.87 MiB
# ⠸ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 8.95 MiB/9.21 MiB
# babel                     ------------------------------ 7.87 MiB/9.72 MiB
# jupyterlab                ------------------------------ 9.89 MiB/11.87 MiB
# ⠸ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 9.03 MiB/9.21 MiB
# babel                     ------------------------------ 8.24 MiB/9.72 MiB
# jupyterlab                ------------------------------ 11.67 MiB/11.87 MiB
# ⠸ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 9.07 MiB/9.21 MiB
# babel                     ------------------------------ 8.48 MiB/9.72 MiB
# ⠸ Preparing packages... (50/54)
# scikit-learn              ------------------------------ 9.14 MiB/9.21 MiB
# babel                     ------------------------------ 8.62 MiB/9.72 MiB
# ⠼ Preparing packages... (51/54)
# babel                     ------------------------------ 9.24 MiB/9.72 MiB
# ⠼ Preparing packages... (51/54)
# babel                     ------------------------------ 9.33 MiB/9.72 MiB
# ⠼ Preparing packages... (51/54)
# ⠼ Preparing packages... (51/54)
# ⠼ Preparing packages... (51/54)
# ⠼ Preparing packages... (51/54)
# ⠴ Preparing packages... (53/54)
# ⠴ Preparing packages... (53/54)
# ⠴ Preparing packages... (53/54)
# ⠴ Preparing packages... (53/54)
# ⠦ Preparing packages... (53/54)
# ⠦ Preparing packages... (53/54)
# ⠦ Preparing packages... (53/54)
# ⠦ Preparing packages... (53/54)
# ⠧ Preparing packages... (53/54)
# ⠧ Preparing packages... (53/54)
# ⠧ Preparing packages... (53/54)
# ⠧ Preparing packages... (53/54)
# ⠇ Preparing packages... (53/54)
# ⠇ Preparing packages... (53/54)
# ⠇ Preparing packages... (53/54)
# ⠇ Preparing packages... (53/54)
# Prepared 54 packages in 3.45s
# Installed 54 packages in 959ms
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + async-lru==2.3.0
#  + babel==2.18.0
#  + beautifulsoup4==4.14.3
#  + bleach==6.3.0
#  + defusedxml==0.7.1
#  + fastjsonschema==2.21.2
#  + fqdn==1.5.1
#  + ipywidgets==8.1.8
#  + isoduration==20.11.0
#  + joblib==1.5.3
#  + json5==0.13.0
#  + jsonpointer==3.0.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.3.0
#  + jupyter-server==2.17.0
#  + jupyter-server-terminals==0.5.4
#  + jupyterlab==4.5.6
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.28.0
#  + jupyterlab-widgets==3.0.16
#  + lark==1.3.1
#  + mistune==3.2.0
#  + nbclient==0.10.4
#  + nbconvert==7.17.0
#  + nbformat==5.10.4
#  + notebook-shim==0.2.4
#  + overrides==7.7.0
#  + pandocfilters==1.5.1
#  + prometheus-client==0.24.1
#  + python-json-logger==4.0.0
#  + referencing==0.37.0
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rpds-py==0.30.0
#  + scikit-learn==1.7.2
#  + scipy==1.15.3
#  + send2trash==2.1.0
#  + soupsieve==2.8.3
#  + terminado==0.18.1
#  + threadpoolctl==3.6.0
#  + tinycss2==1.4.0
#  + tomli==2.4.0
#  + tzdata==2025.3
#  + uri-template==1.3.0
#  + webcolors==25.10.0
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
#  + widgetsnbextension==4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn

try:
    from mamba_ssm import Mamba
except ImportError:
    raise ImportError("Please install mamba_ssm and causal-conv1d to use this model.")

class IOHMambaPredictor(nn.Module):
    def __init__(self, input_dim=4, model_dim_1=32, model_dim_2=64):
        super(IOHMambaPredictor, self).__init__()
        
        # 1. Initial Projection 
        self.input_projection_1 = nn.Linear(input_dim, model_dim_1)
        self.norm_1 = nn.LayerNorm(model_dim_1)
        
        # 2. Mamba Block 1
        self.mamba_1 = Mamba(
            d_model=model_dim_1,
            d_state=16,
            d_conv=4,
            expand=2
        )

        # 3. Projection to larger dimension
        self.input_projection_2 = nn.Linear(model_dim_1, model_dim_2)
        self.norm_2 = nn.LayerNorm(model_dim_2)
        
        # 4. Mamba Block 2
        self.mamba_2 = Mamba(
            d_model=model_dim_2,
            d_state=16,
            d_conv=4,
            expand=2
        )
        
        # 5. Final Output Projection (Late Fusion - Identical to Transformer)
        self.output_projection = nn.Sequential(
            nn.Linear(model_dim_2 + 5, model_dim_2 // 2),
            nn.ELU(),
            nn.Linear(model_dim_2 // 2, 1)
        )
    
    def forward(self, x_seq, x_static):
        # Sequence: (B, 900, 4)
        x = self.input_projection_1(x_seq) # (B, 900, 64)
        x = self.norm_1(x)
        x = self.mamba_1(x)                # (B, 900, 64)
        
        x = self.input_projection_2(x)     # (B, 900, 64)
        x = self.norm_2(x)
        x = self.mamba_2(x)                # (B, 900, 64)

        # 1. Pool the time-series sequence
        x = torch.mean(x, dim=1)           # (B, 64)

        # 2. Concatenate static demographics
        x = torch.concat([x, x_static], dim=-1)  # (B, 69)

        # 3. Final prediction
        output = self.output_projection(x) # (B, 1)
        
        return output.squeeze(-1)          # (B)

if __name__ == "__main__":
    # Mamba requires CUDA. It will crash on CPU due to the custom kernels.
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    model = IOHMambaPredictor().to(device)
    
    # Calculate trainable parameters
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Mamba Model Parameters: {total_params:,}")
    
    if device.type == "cuda":
        dummy_seq = torch.randn(32, 900, 4).to(device)
        dummy_static = torch.randn(32, 5).to(device)
        
        out = model(dummy_seq, dummy_static)
        print(f"Output Shape: {out.shape} (Expected: [32])")
    else:
        print("Warning: CUDA not detected. Mamba forward pass skipped.")
# Out:
# Mamba Model Parameters: 47,297
# Output Shape: torch.Size([32]) (Expected: [32])

# %%
import os
from typing import Dict
import torch
from torch.utils.data import Dataset
from tqdm.auto import tqdm

class IOHDataset(Dataset):
    def __init__(self, data_dir: str, manifest: Dict[int, int]):
        super().__init__()
        self.data_dir = data_dir
        
        # 1. Calculate total windows to pre-allocate exact memory
        total_windows = sum(manifest.values())
        print(f"Pre-allocating RAM for {total_windows} windows...")

        # 2. Pre-allocate massive empty tensors (Zero memory spike!)
        self.X_seq = torch.empty((total_windows, 900, 4), dtype=torch.float32)
        self.X_static = torch.empty((total_windows, 5), dtype=torch.float32)
        self.Y = torch.empty((total_windows,), dtype=torch.long)

        # 3. Fill the tensors directly from disk
        current_idx = 0
        for case_id in tqdm(sorted(manifest.keys())):
            n_windows = manifest[case_id]
            if n_windows == 0:
                continue
                
            path = os.path.join(data_dir, f"case_{case_id}.pt")
            data = torch.load(path, weights_only=True)
            assert data["X_seq"].shape[0] == n_windows, \
                f"case_{case_id}: manifest says {n_windows} windows but file has {data['X_seq'].shape[0]}"
            
            # Slot the data into the pre-allocated block
            end_idx = current_idx + n_windows
            self.X_seq[current_idx:end_idx] = data["X_seq"]
            self.X_static[current_idx:end_idx] = data["X_static"]
            self.Y[current_idx:end_idx] = data["Y"]
            
            current_idx = end_idx

        print(f"Dataset successfully loaded into RAM. Size: {self.X_seq.element_size() * self.X_seq.nelement() / 1e9:.2f} GB")

    def __len__(self) -> int:
        return len(self.Y)

    def __getitem__(self, idx: int):
        return self.X_seq[idx], self.X_static[idx], self.Y[idx]

# %%
import os
import random
import pickle
import time  # <-- Added for timing
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import average_precision_score, roc_auc_score
import numpy as np
import functools
from tqdm.auto import tqdm

TRAIN_DIR = "/mnt/dataforioh/processed_data_denovo/train"
TEST_DIR = "/mnt/dataforioh/processed_data_denovo/test"
OUTPUT_DIR = "/mnt/dataforioh/processed_data_denovo"

# 1. CONFIGURATION & HYPERPARAMETERS
BATCH_SIZE = 32
LEARNING_RATE = 1e-4
EPOCHS = 50
PATIENCE = 5  # Early stopping patience
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")

def set_seed(seed=42, deterministic=True):
    os.environ["PYTHONHASHSEED"] = str(seed)

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    
    if deterministic:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    else:
        torch.backends.cudnn.deterministic = False
        torch.backends.cudnn.benchmark = True

def main(seed):
    print(f"========== Starting Training on {DEVICE} ==========")

    # 2. LOAD METADATA & PATIENT-LEVEL SPLIT
    meta_path = os.path.join(OUTPUT_DIR, "pipeline_meta.pkl")
    with open(meta_path, "rb") as f:
        meta = pickle.load(f)

    full_train_manifest = meta["manifest"]["train"]
    test_manifest = meta["manifest"]["test"]

    # Extract patient IDs (keys) from the training manifest
    train_case_ids = list(full_train_manifest.keys())

    # Patient-Level Validation Split (80% Train, 20% Val)
    actual_train_ids, val_ids = train_test_split(train_case_ids, test_size=0.2, random_state=seed)

    # Rebuild the manifests for Train and Val
    train_manifest = {cid: full_train_manifest[cid] for cid in actual_train_ids}
    val_manifest = {cid: full_train_manifest[cid] for cid in val_ids}

    print(f"Patients -> Train: {len(actual_train_ids)} | Val: {len(val_ids)} | Test: {len(test_manifest.keys())}")

    # 3. BUILD DATALOADERS
    train_ds = IOHDataset(TRAIN_DIR, train_manifest)
    val_ds = IOHDataset(TRAIN_DIR, val_manifest)  # Val uses TRAIN_DIR because it was split from train
    test_ds = IOHDataset(TEST_DIR, test_manifest)

    # Pin memory speeds up CPU-to-GPU data transfers
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)
    
    # 4. MODEL, LOSS, & OPTIMIZER SETUP
    model = IOHMambaPredictor(input_dim=2, model_dim_1=32, model_dim_2=64)
    model.to(DEVICE)

    # BCEWithLogitsLoss is required for binary classification with raw logit outputs
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3, factor=0.5)

    # 5. TRAINING & VALIDATION LOOP (WITH EARLY STOPPING)
    best_val_auprc = 0.0
    epochs_no_improve = 0

    min_delta = 0.001

    for epoch in range(EPOCHS):
        # --- START TIMING & RESET VRAM ---
        epoch_start_time = time.time()
        if DEVICE.type == "cuda":
            torch.cuda.reset_peak_memory_stats(DEVICE)

        # --- TRAINING PHASE ---
        model.train()
        train_loss = 0.0
        
        for X_seq, X_static, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS} Training"):
            X_seq, X_static = X_seq.to(DEVICE), X_static.to(DEVICE)
            # CRITICAL: Cast int64 labels to float32 for BCEWithLogitsLoss
            labels = labels.float().to(DEVICE)

            optimizer.zero_grad()
            X_seq = X_seq[:, :, :2]
            logits = model(X_seq, X_static)
            
            loss = criterion(logits, labels)
            loss.backward()
            
            # CRITICAL FIX: Gradient clipping to prevent Mamba NaN errors
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            
            train_loss += loss.item() * X_seq.size(0)
            
        train_loss /= len(train_loader.dataset)

        # --- VALIDATION PHASE ---
        model.eval()
        val_loss = 0.0
        all_val_preds = []
        all_val_labels = []

        with torch.no_grad():
            for X_seq, X_static, labels in val_loader:
                X_seq, X_static = X_seq.to(DEVICE), X_static.to(DEVICE)
                labels = labels.float().to(DEVICE)

                X_seq = X_seq[:, :, :2]
                logits = model(X_seq, X_static)
                loss = criterion(logits, labels)
                val_loss += loss.item() * X_seq.size(0)

                # Convert logits to probabilities using Sigmoid for metrics
                probs = torch.sigmoid(logits)
                all_val_preds.extend(probs.cpu().numpy())
                all_val_labels.extend(labels.cpu().numpy())

        val_loss /= len(val_loader.dataset)
        
        # Calculate Metrics
        val_auprc = average_precision_score(all_val_labels, all_val_preds)
        val_auroc = roc_auc_score(all_val_labels, all_val_preds)

        scheduler.step(val_auprc)

        # --- END TIMING & GRAB PEAK VRAM ---
        epoch_duration = time.time() - epoch_start_time
        if DEVICE.type == "cuda":
            peak_vram_mb = torch.cuda.max_memory_allocated(DEVICE) / (1024 * 1024)
        else:
            peak_vram_mb = 0.0

        print(f"Epoch [{epoch+1}/{EPOCHS}] | Time: {epoch_duration:.2f}s | Peak VRAM: {peak_vram_mb:.1f} MB")
        print(f"             | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val AUPRC: {val_auprc:.4f} | Val AUROC: {val_auroc:.4f}")

        # --- EARLY STOPPING CHECK ---
        if val_auprc > (best_val_auprc + min_delta):
            best_val_auprc = val_auprc
            epochs_no_improve = 0
            torch.save(model.state_dict(), f"PM_47k_D2_MAPHRonly_{seed}.pth")
            print("  -> Validation AUPRC improved. Model saved.")
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= PATIENCE:
                print(f"\nEarly stopping triggered after {epoch+1} epochs.")
                break

    # 6. FINAL TESTING PHASE (BLIND VAULT)
    print("\n========== Evaluating on Holdout Test Set ==========")
    # Load the best weights discovered during validation
    model.load_state_dict(torch.load(f"PM_47k_D2_MAPHRonly_{seed}.pth", weights_only=True))
    model.eval()
    
    all_test_preds = []
    all_test_labels = []

    with torch.no_grad():
        for X_seq, X_static, labels in tqdm(test_loader, desc=f"Testing: "):
            X_seq, X_static = X_seq.to(DEVICE), X_static.to(DEVICE)
            labels = labels.float().to(DEVICE)

            X_seq = X_seq[:, :, :2]
            logits = model(X_seq, X_static)
            probs = torch.sigmoid(logits)
            
            all_test_preds.extend(probs.cpu().numpy())
            all_test_labels.extend(labels.cpu().numpy())

    test_auprc = average_precision_score(all_test_labels, all_test_preds)
    test_auroc = roc_auc_score(all_test_labels, all_test_preds)

    print(f"FINAL TEST METRICS | AUPRC: {test_auprc:.4f} | AUROC: {test_auroc:.4f}")
    print("====================================================")
    return test_auprc, test_auroc

if __name__ == "__main__":
    SEEDS = [42, 123, 7]
    AUPRCS = []
    AUROCS = []
    
    for seed in SEEDS:
        set_seed(seed)
        test_auprc, test_auroc = main(seed)
        AUPRCS.append(test_auprc)
        AUROCS.append(test_auroc)
        print(f"Seed {seed} -> AUPRC: {test_auprc:.4f} | AUROC: {test_auroc:.4f}")
    
    print(f"\nFinal Results across {len(SEEDS)} seeds:")
    print(f"AUPRC: {np.mean(AUPRCS):.4f} +/- {np.std(AUPRCS):.4f}")
    print(f"AUROC: {np.mean(AUROCS):.4f} +/- {np.std(AUROCS):.4f}")
# Out:
# ========== Starting Training on cuda ==========
# Patients -> Train: 2176 | Val: 545 | Test: 698
# Pre-allocating RAM for 75844 windows...
#   0%|          | 0/2176 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 1.09 GB
# Pre-allocating RAM for 20172 windows...
#   0%|          | 0/545 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 0.29 GB
# Pre-allocating RAM for 92751 windows...
#   0%|          | 0/698 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 1.34 GB
# Epoch 1/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [1/50] | Time: 21.29s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5272 | Val Loss: 0.5341 | Val AUPRC: 0.4314 | Val AUROC: 0.6844
#   -> Validation AUPRC improved. Model saved.
# Epoch 2/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [2/50] | Time: 20.27s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5181 | Val Loss: 0.5307 | Val AUPRC: 0.4396 | Val AUROC: 0.6899
#   -> Validation AUPRC improved. Model saved.
# Epoch 3/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [3/50] | Time: 19.59s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5167 | Val Loss: 0.5258 | Val AUPRC: 0.4481 | Val AUROC: 0.6983
#   -> Validation AUPRC improved. Model saved.
# Epoch 4/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [4/50] | Time: 18.59s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5137 | Val Loss: 0.5301 | Val AUPRC: 0.4499 | Val AUROC: 0.7037
#   -> Validation AUPRC improved. Model saved.
# Epoch 5/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [5/50] | Time: 19.00s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5125 | Val Loss: 0.5252 | Val AUPRC: 0.4498 | Val AUROC: 0.7038
# Epoch 6/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [6/50] | Time: 19.37s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5116 | Val Loss: 0.5242 | Val AUPRC: 0.4564 | Val AUROC: 0.7062
#   -> Validation AUPRC improved. Model saved.
# Epoch 7/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [7/50] | Time: 19.43s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5112 | Val Loss: 0.5257 | Val AUPRC: 0.4548 | Val AUROC: 0.7069
# Epoch 8/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [8/50] | Time: 20.09s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5107 | Val Loss: 0.5200 | Val AUPRC: 0.4599 | Val AUROC: 0.7076
#   -> Validation AUPRC improved. Model saved.
# Epoch 9/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [9/50] | Time: 20.12s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5100 | Val Loss: 0.5201 | Val AUPRC: 0.4586 | Val AUROC: 0.7081
# Epoch 10/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [10/50] | Time: 20.12s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5093 | Val Loss: 0.5194 | Val AUPRC: 0.4581 | Val AUROC: 0.7092
# Epoch 11/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [11/50] | Time: 19.50s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5086 | Val Loss: 0.5190 | Val AUPRC: 0.4605 | Val AUROC: 0.7096
# Epoch 12/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [12/50] | Time: 20.03s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5073 | Val Loss: 0.5188 | Val AUPRC: 0.4643 | Val AUROC: 0.7125
#   -> Validation AUPRC improved. Model saved.
# Epoch 13/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [13/50] | Time: 19.65s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5061 | Val Loss: 0.5169 | Val AUPRC: 0.4662 | Val AUROC: 0.7133
#   -> Validation AUPRC improved. Model saved.
# Epoch 14/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [14/50] | Time: 19.17s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5052 | Val Loss: 0.5161 | Val AUPRC: 0.4668 | Val AUROC: 0.7162
# Epoch 15/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [15/50] | Time: 19.46s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5040 | Val Loss: 0.5209 | Val AUPRC: 0.4623 | Val AUROC: 0.7118
# Epoch 16/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [16/50] | Time: 20.03s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5032 | Val Loss: 0.5157 | Val AUPRC: 0.4666 | Val AUROC: 0.7163
# Epoch 17/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [17/50] | Time: 20.20s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5021 | Val Loss: 0.5162 | Val AUPRC: 0.4656 | Val AUROC: 0.7159
# Epoch 18/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [18/50] | Time: 21.25s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5007 | Val Loss: 0.5166 | Val AUPRC: 0.4689 | Val AUROC: 0.7171
#   -> Validation AUPRC improved. Model saved.
# Epoch 19/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [19/50] | Time: 20.40s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.4993 | Val Loss: 0.5167 | Val AUPRC: 0.4677 | Val AUROC: 0.7178
# Epoch 20/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [20/50] | Time: 20.64s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.4983 | Val Loss: 0.5148 | Val AUPRC: 0.4693 | Val AUROC: 0.7186
# Epoch 21/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [21/50] | Time: 19.98s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.4972 | Val Loss: 0.5163 | Val AUPRC: 0.4694 | Val AUROC: 0.7196
# Epoch 22/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [22/50] | Time: 19.67s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.4962 | Val Loss: 0.5154 | Val AUPRC: 0.4697 | Val AUROC: 0.7179
# Epoch 23/50 Training:   0%|          | 0/2371 [00:00<?, ?it/s]
# Epoch [23/50] | Time: 20.21s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.4949 | Val Loss: 0.5154 | Val AUPRC: 0.4651 | Val AUROC: 0.7173
#
# Early stopping triggered after 23 epochs.
#
# ========== Evaluating on Holdout Test Set ==========
# Testing:   0%|          | 0/2899 [00:00<?, ?it/s]
# FINAL TEST METRICS | AUPRC: 0.1545 | AUROC: 0.7083
# ====================================================
# Seed 42 -> AUPRC: 0.1545 | AUROC: 0.7083
# ========== Starting Training on cuda ==========
# Patients -> Train: 2176 | Val: 545 | Test: 698
# Pre-allocating RAM for 76783 windows...
#   0%|          | 0/2176 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 1.11 GB
# Pre-allocating RAM for 19233 windows...
#   0%|          | 0/545 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 0.28 GB
# Pre-allocating RAM for 92751 windows...
#   0%|          | 0/698 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 1.34 GB
# Epoch 1/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [1/50] | Time: 19.59s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5344 | Val Loss: 0.5072 | Val AUPRC: 0.4346 | Val AUROC: 0.7021
#   -> Validation AUPRC improved. Model saved.
# Epoch 2/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [2/50] | Time: 19.62s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5247 | Val Loss: 0.5057 | Val AUPRC: 0.4397 | Val AUROC: 0.7067
#   -> Validation AUPRC improved. Model saved.
# Epoch 3/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [3/50] | Time: 19.91s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5232 | Val Loss: 0.5046 | Val AUPRC: 0.4416 | Val AUROC: 0.7081
#   -> Validation AUPRC improved. Model saved.
# Epoch 4/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [4/50] | Time: 19.64s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5219 | Val Loss: 0.5026 | Val AUPRC: 0.4477 | Val AUROC: 0.7105
#   -> Validation AUPRC improved. Model saved.
# Epoch 5/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [5/50] | Time: 20.56s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5206 | Val Loss: 0.5007 | Val AUPRC: 0.4484 | Val AUROC: 0.7123
# Epoch 6/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [6/50] | Time: 19.61s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5190 | Val Loss: 0.4996 | Val AUPRC: 0.4532 | Val AUROC: 0.7153
#   -> Validation AUPRC improved. Model saved.
# Epoch 7/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [7/50] | Time: 19.77s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5183 | Val Loss: 0.4999 | Val AUPRC: 0.4566 | Val AUROC: 0.7175
#   -> Validation AUPRC improved. Model saved.
# Epoch 8/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [8/50] | Time: 19.89s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5174 | Val Loss: 0.5023 | Val AUPRC: 0.4543 | Val AUROC: 0.7172
# Epoch 9/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [9/50] | Time: 19.74s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5160 | Val Loss: 0.4969 | Val AUPRC: 0.4584 | Val AUROC: 0.7179
#   -> Validation AUPRC improved. Model saved.
# Epoch 10/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [10/50] | Time: 19.85s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5150 | Val Loss: 0.4952 | Val AUPRC: 0.4618 | Val AUROC: 0.7208
#   -> Validation AUPRC improved. Model saved.
# Epoch 11/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [11/50] | Time: 19.76s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5142 | Val Loss: 0.4977 | Val AUPRC: 0.4583 | Val AUROC: 0.7237
# Epoch 12/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [12/50] | Time: 19.52s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5138 | Val Loss: 0.4938 | Val AUPRC: 0.4631 | Val AUROC: 0.7236
#   -> Validation AUPRC improved. Model saved.
# Epoch 13/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [13/50] | Time: 19.65s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5127 | Val Loss: 0.4959 | Val AUPRC: 0.4591 | Val AUROC: 0.7200
# Epoch 14/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [14/50] | Time: 19.57s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5123 | Val Loss: 0.4972 | Val AUPRC: 0.4604 | Val AUROC: 0.7200
# Epoch 15/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [15/50] | Time: 19.60s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5114 | Val Loss: 0.4977 | Val AUPRC: 0.4596 | Val AUROC: 0.7192
# Epoch 16/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [16/50] | Time: 19.55s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5106 | Val Loss: 0.4981 | Val AUPRC: 0.4546 | Val AUROC: 0.7194
# Epoch 17/50 Training:   0%|          | 0/2400 [00:00<?, ?it/s]
# Epoch [17/50] | Time: 19.46s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5086 | Val Loss: 0.4993 | Val AUPRC: 0.4509 | Val AUROC: 0.7182
#
# Early stopping triggered after 17 epochs.
#
# ========== Evaluating on Holdout Test Set ==========
# Testing:   0%|          | 0/2899 [00:00<?, ?it/s]
# FINAL TEST METRICS | AUPRC: 0.1476 | AUROC: 0.6998
# ====================================================
# Seed 123 -> AUPRC: 0.1476 | AUROC: 0.6998
# ========== Starting Training on cuda ==========
# Patients -> Train: 2176 | Val: 545 | Test: 698
# Pre-allocating RAM for 77168 windows...
#   0%|          | 0/2176 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 1.11 GB
# Pre-allocating RAM for 18848 windows...
#   0%|          | 0/545 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 0.27 GB
# Pre-allocating RAM for 92751 windows...
#   0%|          | 0/698 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 1.34 GB
# Epoch 1/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [1/50] | Time: 19.49s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5309 | Val Loss: 0.5103 | Val AUPRC: 0.3841 | Val AUROC: 0.6763
#   -> Validation AUPRC improved. Model saved.
# Epoch 2/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [2/50] | Time: 19.46s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5225 | Val Loss: 0.5097 | Val AUPRC: 0.3890 | Val AUROC: 0.6759
#   -> Validation AUPRC improved. Model saved.
# Epoch 3/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [3/50] | Time: 19.50s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5201 | Val Loss: 0.5065 | Val AUPRC: 0.3983 | Val AUROC: 0.6812
#   -> Validation AUPRC improved. Model saved.
# Epoch 4/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [4/50] | Time: 19.49s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5188 | Val Loss: 0.5049 | Val AUPRC: 0.4120 | Val AUROC: 0.6898
#   -> Validation AUPRC improved. Model saved.
# Epoch 5/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [5/50] | Time: 19.55s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5167 | Val Loss: 0.5074 | Val AUPRC: 0.4101 | Val AUROC: 0.6918
# Epoch 6/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [6/50] | Time: 19.51s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5154 | Val Loss: 0.5076 | Val AUPRC: 0.4053 | Val AUROC: 0.6895
# Epoch 7/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [7/50] | Time: 19.48s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5144 | Val Loss: 0.4998 | Val AUPRC: 0.4136 | Val AUROC: 0.6969
#   -> Validation AUPRC improved. Model saved.
# Epoch 8/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [8/50] | Time: 19.44s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5134 | Val Loss: 0.5001 | Val AUPRC: 0.4122 | Val AUROC: 0.6972
# Epoch 9/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [9/50] | Time: 19.57s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5130 | Val Loss: 0.5030 | Val AUPRC: 0.4113 | Val AUROC: 0.6982
# Epoch 10/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [10/50] | Time: 19.55s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5122 | Val Loss: 0.4998 | Val AUPRC: 0.4116 | Val AUROC: 0.7000
# Epoch 11/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [11/50] | Time: 19.42s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5117 | Val Loss: 0.5028 | Val AUPRC: 0.4147 | Val AUROC: 0.7009
#   -> Validation AUPRC improved. Model saved.
# Epoch 12/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [12/50] | Time: 19.37s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5110 | Val Loss: 0.5018 | Val AUPRC: 0.4153 | Val AUROC: 0.6980
# Epoch 13/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [13/50] | Time: 19.53s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5102 | Val Loss: 0.5021 | Val AUPRC: 0.4065 | Val AUROC: 0.6962
# Epoch 14/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [14/50] | Time: 19.51s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5097 | Val Loss: 0.5000 | Val AUPRC: 0.4077 | Val AUROC: 0.7012
# Epoch 15/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [15/50] | Time: 19.51s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5094 | Val Loss: 0.5030 | Val AUPRC: 0.4142 | Val AUROC: 0.7013
# Epoch 16/50 Training:   0%|          | 0/2412 [00:00<?, ?it/s]
# Epoch [16/50] | Time: 19.48s | Peak VRAM: 358.1 MB
#              | Train Loss: 0.5088 | Val Loss: 0.5059 | Val AUPRC: 0.4063 | Val AUROC: 0.6954
#
# Early stopping triggered after 16 epochs.
#
# ========== Evaluating on Holdout Test Set ==========
# Testing:   0%|          | 0/2899 [00:00<?, ?it/s]
# FINAL TEST METRICS | AUPRC: 0.1475 | AUROC: 0.7006
# ====================================================
# Seed 7 -> AUPRC: 0.1475 | AUROC: 0.7006
#
# Final Results across 3 seeds:
# AUPRC: 0.1499 +/- 0.0033
# AUROC: 0.7029 +/- 0.0038

# %%
def test_eval(ckpt_path, test_loader):
    # 6. FINAL TESTING PHASE (BLIND VAULT)
    print("\n========== Evaluating on Holdout Test Set ==========")
    # Load the best weights discovered during validation
    model.load_state_dict(torch.load("best_transformer_weights.pth", weights_only=True))
    model.eval().to(DEVICE)
    
    all_test_preds = []
    all_test_labels = []

    with torch.no_grad():
        for X_seq, X_static, labels in tqdm(test_loader):
            X_seq, X_static = X_seq.to(DEVICE), X_static.to(DEVICE)
            labels = labels.float().to(DEVICE)

            logits = model(X_seq, X_static)
            probs = torch.sigmoid(logits)
            
            all_test_preds.extend(probs.cpu().numpy())
            all_test_labels.extend(labels.cpu().numpy())

    all_test_preds  = np.array(all_test_preds)
    all_test_labels = np.array(all_test_labels)

    # ── Point estimates ───────────────────────────────────────────────────────
    test_auprc  = average_precision_score(all_test_labels, all_test_preds)
    test_auroc  = roc_auc_score(all_test_labels, all_test_preds)

    # Accuracy at 0.5 decision threshold
    binary_preds = (all_test_preds >= 0.5).astype(int)
    test_accuracy = (binary_preds == all_test_labels.astype(int)).mean()

    # ── Bootstrap Confidence Intervals (95%, 2000 resamples) ─────────────────
    N_BOOTSTRAP  = 2000
    CI_ALPHA     = 0.05          # 95% CI
    rng          = np.random.default_rng(seed=42)
    n_samples    = len(all_test_labels)

    boot_auroc, boot_auprc, boot_acc = [], [], []

    for _ in tqdm(range(N_BOOTSTRAP)):
        idx = rng.integers(0, n_samples, size=n_samples)   # resample with replacement
        b_labels = all_test_labels[idx]
        b_preds  = all_test_preds[idx]

        # Skip degenerate bootstrap draws that contain only one class
        if len(np.unique(b_labels)) < 2:
            continue

        boot_auroc.append(roc_auc_score(b_labels, b_preds))
        boot_auprc.append(average_precision_score(b_labels, b_preds))
        boot_acc.append(((b_preds >= 0.5).astype(int) == b_labels.astype(int)).mean())

    boot_auroc = np.array(boot_auroc)
    boot_auprc = np.array(boot_auprc)
    boot_acc   = np.array(boot_acc)

    lo, hi = CI_ALPHA / 2, 1 - CI_ALPHA / 2          # 2.5th and 97.5th percentiles

    auroc_ci = (np.percentile(boot_auroc, lo * 100), np.percentile(boot_auroc, hi * 100))
    auprc_ci = (np.percentile(boot_auprc, lo * 100), np.percentile(boot_auprc, hi * 100))
    acc_ci   = (np.percentile(boot_acc,   lo * 100), np.percentile(boot_acc,   hi * 100))

    # ── Print results ─────────────────────────────────────────────────────────
    print(f"\n{'Metric':<12} {'Score':>8}   {'95% CI':>22}")
    print("-" * 46)
    print(f"{'AUROC':<12} {test_auroc:>8.4f}   ({auroc_ci[0]:.4f} – {auroc_ci[1]:.4f})")
    print(f"{'AUPRC':<12} {test_auprc:>8.4f}   ({auprc_ci[0]:.4f} – {auprc_ci[1]:.4f})")
    print(f"{'Accuracy':<12} {test_accuracy:>8.4f}   ({acc_ci[0]:.4f} – {acc_ci[1]:.4f})")
    print("-" * 46)
    print(f"Bootstrap resamples : {len(boot_auroc):,}  (seed=42, threshold=0.50)")
    print("====================================================")

meta_path = os.path.join(OUTPUT_DIR, "pipeline_meta.pkl")
with open(meta_path, "rb") as f:
    meta = pickle.load(f)

test_manifest = meta["manifest"]["test"]
test_ds = IOHDataset(TEST_DIR, test_manifest)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)

test_eval('/root/best_transformer_weights.pth', test_loader)
# Out:
# Pre-allocating RAM for 17461 windows...
#   0%|          | 0/102 [00:00<?, ?it/s]
# Dataset successfully loaded into RAM. Size: 0.25 GB
#
# ========== Evaluating on Holdout Test Set ==========
#   0%|          | 0/546 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Metric          Score                   95% CI
# ----------------------------------------------
# AUROC          0.7934   (0.7821 – 0.8039)
# AUPRC          0.3930   (0.3714 – 0.4163)
# Accuracy       0.8370   (0.8317 – 0.8421)
# ----------------------------------------------
# Bootstrap resamples : 2,000  (seed=42, threshold=0.50)
# ====================================================
